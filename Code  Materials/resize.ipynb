# %%
from PIL import Image
import os

# %%
foldername = "data_432x368"
mainfolder = "/content/drive/MyDrive/FYP/Data"
drivepath = "/content/drive/MyDrive/FYP/"+foldername

if foldername =="data_224x224":
  w,h = 224,224
else:
  w,h = 432,368

# %%
stance = "Stance"
execution = "Execution"
correctexecution = "Execution correct"
incorrectexecution = "Execution incorrect"
correctstance = "stance correct"
incorrectstance = "stance incorrect"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(len(os.listdir(mainfolder+"/"+incorrectstance)))
for count,file in enumerate(os.listdir(mainfolder+"/"+incorrectstance)):
  try:
    image = Image.open(f"{mainfolder}/{incorrectstance}/{file}")
    new_image = image.resize((w, h))
    new_image.save(f'{drivepath}/{incorrectstance}/image_{count}.jpg')
    print(f"image_{count}.jpg save")
  except:
    print(f"{file} corrupted")
# Out:
# 500
# image_0.jpg save
# image_1.jpg save
# image_2.jpg save
# image_3.jpg save
# image_4.jpg save
# image_5.jpg save
# image_6.jpg save
# image_7.jpg save
# image_8.jpg save
# image_9.jpg save
# image_10.jpg save
# image_11.jpg save
# image_12.jpg save
# image_13.jpg save
# image_14.jpg save
# image_15.jpg save
# image_16.jpg save
# image_17.jpg save
# image_18.jpg save
# image_19.jpg save
# image_20.jpg save
# image_21.jpg save
# image_22.jpg save
# image_23.jpg save
# image_24.jpg save
# image_25.jpg save
# image_26.jpg save
# image_27.jpg save
# image_28.jpg save
# image_29.jpg save
# image_30.jpg save
# image_31.jpg save
# image_32.jpg save
# image_33.jpg save
# image_34.jpg save
# image_35.jpg save
# image_36.jpg save
# image_37.jpg save
# image_38.jpg save
# image_39.jpg save
# image_40.jpg save
# image_41.jpg save
# image_42.jpg save
# image_43.jpg save
# image_44.jpg save
# image_45.jpg save
# image_46.jpg save
# image_47.jpg save
# image_48.jpg save
# image_49.jpg save
# ...
